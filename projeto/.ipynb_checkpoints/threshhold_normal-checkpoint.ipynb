# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
def J_T(h1,h2):
    # ordenei os histogramas pro plot depois
    J=[]
    T=np.concatenate((sorted(h1),sorted(h2)))
    for T in range(0,256):
        P1=0
        P2=0
        mean1=0
        mean2=0
        var1=0
        var2=0
        
        for i in h1:
            if i<=T:
                P1=P1+(np.count_nonzero(h1==i)/len(h1))
        for i in h1:
            if i<=T:
                mean1=mean1+ (((np.count_nonzero(h1==i)/len(h1))*i)/P1)
        for i in h1:
            if i<=T:
                var1=var1+ ((((i-mean1)**2)*(np.count_nonzero(h1==i)/len(h1)))/P1)
                
        for i in h2:
            if i>T:
                P2=P2+(np.count_nonzero(h2==i)/len(h2))
        for i in h2:
            if i>T:
                mean2=mean2+ (((np.count_nonzero(h2==i)/len(h2))*i)/P2)
        for i in h2:
            if i>T:
                var2=var2+ ((((i-mean2)**2)*(np.count_nonzero(h2==i)/len(h2)))/P2)
                
        j=1+2*((P1*np.log(math.sqrt(var1)))+(P2*np.log(math.sqrt(var2))))-2*(P1*np.log(P1)+P2*np.log(P2))
        J.append(j)
        
    return J

# %%
def print_graf():
    best_t = np.concatenate((sorted(h1),sorted(h2)))[np.nanargmin(x)]
    sns.distplot(h1, rug=False,kde=True)
    sns.distplot(h2, rug=False,kde=True)
    plt.axvline(best_t, color='k', linestyle='dashed', linewidth=1)
    plt.show()
    return

# %%
h1=np.random.normal(50,15,1000)
h2=np.random.normal(150,15,1000)
h1=np.round(h1)
h2=np.round(h2)
x=J_T(h1,h2)
plt.plot(x)
# Out:
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in log
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars

# %%
print_graf()

# %%
h1=np.random.normal(38,9,1000)
h2=np.random.normal(121,44,1000)
x=J_T(h1,h2)
plt.plot(x)
# Out:
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in log
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars

# %%
best_t = np.concatenate((sorted(h1),sorted(h2)))[np.nanargmax(x)]
sns.distplot(h1, rug=False,kde=True)
sns.distplot(h2, rug=False,kde=True)
plt.axvline(best_t, color='k', linestyle='dashed', linewidth=1)
plt.show()

# %%
h1=np.random.normal(47,13,1000)
h2=np.random.normal(144,25,1000)
x=J_T(h1,h2)
plt.plot(x)
# Out:
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in log
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars

# %%
best_t = np.concatenate((sorted(h1),sorted(h2)))[np.nanargmax(x)]
sns.distplot(h1, rug=False,kde=True)
sns.distplot(h2, rug=False,kde=True)
plt.axvline(best_t, color='k', linestyle='dashed', linewidth=1)
plt.show()

# %%
h1=np.random.normal(50,4,1000)
h2=np.random.normal(150,30,1000)
x=J_T(h1,h2)
plt.plot(x)
# Out:
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: divide by zero encountered in log
# C:\Users\jutogashi\Anaconda2\envs\p37\lib\site-packages\ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars

# %%
print_graf()
